# %%
# !conda env list
# Out:
# # conda environments:
# #
# # * -> active
# # + -> frozen
# base                     C:\Users\S\miniconda3
# h501-gutenberg       *   C:\Users\S\miniconda3\envs\h501-gutenberg

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Base URL for the raw data
base_url = "https://raw.githubusercontent.com/rfordatascience/tidytuesday/main/data/2025/2025-06-03/"

# Loading the datasets
authors = pd.read_csv(f"{base_url}gutenberg_authors.csv")
languages = pd.read_csv(f"{base_url}gutenberg_languages.csv")
metadata = pd.read_csv(f"{base_url}gutenberg_metadata.csv")
subjects = pd.read_csv(f"{base_url}gutenberg_subjects.csv")

print("Datasets loaded successfully!")
metadata.head()
# Out:
# Datasets loaded successfully!
#    gutenberg_id                                              title  \
# 0             1  The Declaration of Independence of the United ...
# 1             2  The United States Bill of Rights\r\nThe Ten Or...
# 2             3                John F. Kennedy's Inaugural Address
# 3             4  Lincoln's Gettysburg Address\r\nGiven November...
# 4             5                     The United States Constitution
#
#                                author  gutenberg_author_id language  \
# 0                   Jefferson, Thomas               1638.0       en
# 1                       United States                  1.0       en
# 2  Kennedy, John F. (John Fitzgerald)               1666.0       en
# 3                    Lincoln, Abraham                  3.0       en
# 4                       United States                  1.0       en
#
#                                  gutenberg_bookshelf  \
# 0  Politics/American Revolutionary War/United Sta...
# ...

# %%
import gutenberg_tools as gt

# Assuming your DataFrames are named 'metadata' and 'authors'
ordered_aliases = gt.get_aliases_by_translation_count(metadata, authors)

# Print the top 10 to check the result
print(ordered_aliases[:10])
# Out:
# ['Grimm, Wilhelm Carl', 'Grimm, Jacob Ludwig Carl', 'Andersen, Hans Christian', 'Alighieri, Dante', 'Poe, Edgar Allen', 'Stevenson, R. L. (Robert Louis)', "Wilde, Oscar Fingal O'Flahertie Wills", 'Όμηρος', 'Erasmus, of Rotterdam', 'Chaney, John Griffith']
